# %%
set_nb_theme('monokai')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #f8f8f0;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #f8f8f0;
#  background-color: #1e1e1e;
#  background: #1e1e1e;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1e1e1e;
#  background: #1e1e1e;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #f8f8f0;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #f8f8f0;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
nba = pd.read_csv('nba.csv')
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
pd.read_csv('revenue.csv')
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/16       985          122    499
# 1   1/2/16       738          788    534
# 2   1/3/16        14           20    933
# 3   1/4/16       730          904    885
# 4   1/5/16       114           71    253
# 5   1/6/16       936          502    497
# 6   1/7/16       123          996    115
# 7   1/8/16       935          492    886
# 8   1/9/16       846          954    823
# 9  1/10/16        54          285    216

# %%
nba[['Name', 'Team']].head()
output = None

# %%
nba['Sport'] = 'Basketball'

# %%
nba.head()
output = None

# %%
nba['Team'].value_counts()
output = None

# %%
nba.dropna(axis = 1)
# Out:
#           Sport
# 0    Basketball
# 1    Basketball
# 2    Basketball
# 3    Basketball
# 4    Basketball
# ..          ...
# 453  Basketball
# 454  Basketball
# 455  Basketball
# 456  Basketball
# 457  Basketball
#
# [458 rows x 1 columns]

# %%
nba.fillna(0)
nba['Salary'].fillna(0, inplace=True)

# %%
nba['Salary'] = nba['Salary'].astype('int')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    458 non-null    int64
#  9   Sport     458 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 35.9+ KB

# %%
employees = pd.read_csv('employees.csv')
employees.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
pd.to_datetime(employees['Start Date']).head(3)
# Out:
# 0   1993-08-06
# 1   1996-03-31
# 2   1993-04-23
# Name: Start Date, dtype: datetime64[ns]

# %%
employees['Start Date'] = pd.to_datetime(employees['Start Date'])
employees.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'])
employees.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-02-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-02-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-02-20 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
employees['Gender'] = employees['Gender'].astype('category')
employees.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-02-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-02-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-02-20 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
employees = pd.read_csv('employees.csv')
employees['Start Date'] = pd.to_datetime(employees['Start Date'])
employees['Last Login Time'] = pd.to_datetime(employees['Last Login Time'])
employees ['Senior Management'] = employees['Senior Management'].astype('bool')
employees['Gender'] = employees['Gender'].astype('category')
employees.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-02-20 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-02-20 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-02-20 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-02-20 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-02-20 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
gem = employees['Team']== 'Marketing'
gen = employees['Gender']== 'Female'
employees[gem & gen].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 43    Marilyn  Female 1980-12-07 2021-02-20 03:16:00   73524    5.207
# 62        NaN  Female 2007-06-12 2021-02-20 17:25:00   58112   19.414
# 98       Tina  Female 2016-06-16 2021-02-20 19:47:00  100705   16.961
#
#     Senior Management       Team
# 43               True  Marketing
# 62               True  Marketing
# 98               True  Marketing

# %%
mgt = employees['Senior Management']
date = employees['Start Date'] < '1990-01-01'
employees[mgt | date].head(3)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2021-02-20 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2021-02-20 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2021-02-20 13:00:00  138705    9.340
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 3               True    Finance

# %%
employees[employees['Team'].isin(['Legal', 'Sales', 'Product'])].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2021-02-20 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2021-02-20 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2021-02-20 15:19:00  102508   12.637
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal

# %%
employees[employees['Salary'].between(60000, 70000)].head(3)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2021-02-20 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2021-02-20 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2021-02-20 09:01:00   63241   15.132
#
#    Senior Management     Team
# 1               True      NaN
# 6               True  Product
# 10              True      NaN

# %%
bond = pd.read_csv('jamesbond.csv', index_col = 'Film')
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.iloc[5:8]
# Out:
#                               Film  Year           Actor       Director  \
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6
# 7       442.5    34.7                5.8

# %%
bond.loc['Goldfinger', 'Actor']
# Out:
# 'Sean Connery'

# %%
bond.loc['Dr. No', 'Actor'] = 'Sir Sean Connery'
bond.loc['Dr. No']
# Out:
# Year                             1962
# Actor                Sir Sean Connery
# Director                Terence Young
# Box Office                      448.8
# Budget                              7
# Bond Actor Salary                 0.6
# Name: Dr. No, dtype: object

# %%
bond.drop('A View to a Kill')
# Out:
#                                  Year             Actor            Director  \
# Film
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971      Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963      Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964      Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# Live and Let Die                 1973       Roger Moore        Guy Hamilton
# ...

# %%
bond.sample(n = 3, axis = 'columns')
# Out:
#                                             Actor  Year  Bond Actor Salary
# Film
# A View to a Kill                      Roger Moore  1985                9.1
# Casino Royale                        Daniel Craig  2006                3.3
# Casino Royale                         David Niven  1967                NaN
# Diamonds Are Forever                 Sean Connery  1971                5.8
# Die Another Day                    Pierce Brosnan  2002               17.9
# Dr. No                           Sir Sean Connery  1962                0.6
# For Your Eyes Only                    Roger Moore  1981                NaN
# From Russia with Love                Sean Connery  1963                1.6
# GoldenEye                          Pierce Brosnan  1995                5.1
# Goldfinger                           Sean Connery  1964                3.2
# Licence to Kill                    Timothy Dalton  1989                7.9
# ...

# %%
chic = pd.read_csv('chicago.csv').dropna(how =  'all')
chic.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chic['Name'].str.len()
# Out:
# 0        15
# 1        17
# 2        14
# 3        19
# 4        19
#          ..
# 32057    19
# 32058    18
# 32059    17
# 32060    19
# 32061    19
# Name: Name, Length: 32062, dtype: int64

# %%
chic['Employee Annual Salary'] = chic['Employee Annual Salary'].str.replace('$', '').astype(float)

# %%
chic['Employee Annual Salary'].mean()
# Out:
# 80204.178633899

# %%
bigmac = pd.read_csv('bigmac.csv', parse_dates = ['Date'], index_col = ['Date', 'Country'])
bigmac.sort_index(inplace=True)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.sort_index(ascending = False)
# Out:
#                           Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                       2.67
#            Venezuela                     0.66
#            Uruguay                       3.74
#            United States                 4.93
#            Ukraine                       1.54
# ...                                       ...
# 2010-01-01 Canada                        3.97
#            Britain                       3.67
#            Brazil                        4.76
#            Australia                     3.98
#            Argentina                     1.84
#
# [652 rows x 1 columns]

# %%
bigmac.index.set_names(names=['Day', 'Location'], inplace = True)

# %%
bigmac.sort_index()
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                     1.84
#            Australia                     3.98
#            Brazil                        4.76
#            Britain                       3.67
#            Canada                        3.97
# ...                                       ...
# 2016-01-01 Ukraine                       1.54
#            United States                 4.93
#            Uruguay                       3.74
#            Venezuela                     0.66
#            Vietnam                       2.67
#
# [652 rows x 1 columns]

# %%
bigmac.loc[('2010-01-01', 'Argentina'), 'Price in US Dollars']
# Out:
# Date        Country
# 2010-01-01  Argentina    1.84
# Name: Price in US Dollars, dtype: float64

# %%
bigmac.transpose()
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
sales = pd.read_csv('salesmen.csv', parse_dates = ['Date'])
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales.pivot(index = 'Date', columns = 'Salesman', values = 'Revenue')
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %%
foods = pd.read_csv('foods.csv')
foods.head(3)
# Out:
#   First Name  Gender      City Frequency     Item  Spend
# 0      Wanda  Female  Stamford    Weekly   Burger  15.66
# 1       Eric    Male  Stamford     Daily  Chalupa  10.56
# 2    Charles    Male  New York     Never    Sushi  42.14

# %%
foods.pivot_table(values = 'Spend', index = ['Gender', 'Item'], aggfunc = 'mean')
# Out:
#                       Spend
# Gender Item
# Female Burger     49.930488
#        Burrito    50.092000
#        Chalupa    54.635000
#        Donut      49.926316
#        Ice Cream  49.788519
#        Sushi      50.355699
# Male   Burger     49.613919
#        Burrito    48.344819
#        Chalupa    49.186761
#        Donut      43.649565
#        Ice Cream  51.096000
#        Sushi      55.614384

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = 'Rank')
sectors = fortune.groupby('Sector')
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.get_group('Technology')
# Out:
#                     Company                                    Industry  \
# Rank
# 3                     Apple                 Computers, Office Equipment
# 18               Amazon.com             Internet Services and Retailing
# 20                       HP                 Computers, Office Equipment
# 25                Microsoft                           Computer Software
# 31                      IBM             Information Technology Services
# ...                     ...                                         ...
# 970       Rackspace Hosting             Internet Services and Retailing
# 971        VeriFone Systems                 Computers, Office Equipment
# 975    Super Micro Computer                 Computers, Office Equipment
# 984   Nuance Communications                           Computer Software
# 990             F5 Networks  Network and Other Communications Equipment
#
#              Location  Revenue  Profits  Employees
# Rank
# ...

# %%
sectors['Employees'].sum().min()
# Out:
# 346397

# %%
week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Restaurant - Customers.csv')
food = pd.read_csv('Restaurant - Foods.csv')
sat = pd.read_csv('Restaurant - Week 1 Satisfaction.csv')

# %%
pd.concat(objs = [week1, week2])
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
week1.merge(week2, how = 'inner', on = ['Customer ID', 'Food ID'])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1.merge(food, how = 'left', on = 'Food ID')
# Out:
#      Customer ID  Food ID   Food Item  Price
# 0            537        9       Donut   0.99
# 1             97        4  Quesadilla   4.25
# 2            658        1       Sushi   3.99
# 3            202        2     Burrito   9.99
# 4            155        9       Donut   0.99
# ..           ...      ...         ...    ...
# 245          413        9       Donut   0.99
# 246          926        6       Pasta  13.99
# 247          134        3        Taco   2.99
# 248          396        6       Pasta  13.99
# 249          535       10       Drink   1.75
#
# [250 rows x 4 columns]

# %%
week1.join(sat)
# Out:
#      Customer ID  Food ID  Satisfaction Rating
# 0            537        9                    2
# 1             97        4                    7
# 2            658        1                    3
# 3            202        2                    7
# 4            155        9                   10
# ..           ...      ...                  ...
# 245          413        9                    1
# 246          926        6                    2
# 247          134        3                    8
# 248          396        6                   10
# 249          535       10                    3
#
# [250 rows x 3 columns]

# %%
import datetime as dt

# %%
date = pd.datetime(2020, 1, 2, 12, 20, 58)
date.year
# Out:
# <ipython-input-88-ac3e257b1522>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   date = pd.datetime(2020, 1, 2, 12, 20, 58)
# 2020

# %%
from pandas_datareader import data

# %%
stocks = data.DataReader(name = 'MSFT', data_source = 'yahoo', start = '2010-01-01', end = '2020-12-31')

# %%
url = 'https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv?accessType=DOWNLOAD'
baby_names = pd.read_csv(url)
baby_names.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.datareader(name = 'BB', data_source = 'yahoo', start = '2007-01-01', end = '2020-12-31')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-e4527eb18f03> in <module>
# ----> 1 data.datareader(name = 'BB', data_source = 'yahoo', start = '2007-01-01', end = '2020-12-31')
#
# AttributeError: module 'pandas_datareader.data' has no attribute 'datareader'
